# %%
import pandas as pd

# %%
# !head -10 ~/shared-data/clickhouse_data/likes.json
# Out:
# {"item_type":"post","owner_id":"-174416405","item_id":"1083","liker_id":"72689","ctime":"0000-00-00 00:00:00","like_date":"0000-00-00 00:00:00","post_date":"2019-03-15 07:34:00"}
# {"item_type":"post","owner_id":"-174416405","item_id":"1103","liker_id":"72689","ctime":"0000-00-00 00:00:00","like_date":"0000-00-00 00:00:00","post_date":"2019-03-17 08:05:00"}
# {"item_type":"post","owner_id":"-170321944","item_id":"328776","liker_id":"72689","ctime":"0000-00-00 00:00:00","like_date":"0000-00-00 00:00:00","post_date":"2019-03-11 23:50:00"}
# {"item_type":"post","owner_id":"-170321944","item_id":"334079","liker_id":"72689","ctime":"0000-00-00 00:00:00","like_date":"0000-00-00 00:00:00","post_date":"2019-03-13 22:15:00"}
# {"item_type":"post","owner_id":"-168996002","item_id":"19811","liker_id":"72689","ctime":"0000-00-00 00:00:00","like_date":"0000-00-00 00:00:00","post_date":"2019-03-05 19:43:00"}
# ...

# %%
# !head -500 ~/shared-data/clickhouse_data/likes.json > ~/likes_sample.json

# %%
likes = pd.read_json("~/likes_sample.json",lines=True)

# %%
likes.head(50)
# Out:
#    item_type   owner_id  item_id  liker_id                ctime  \
# 0       post -174416405     1083     72689  0000-00-00 00:00:00
# 1       post -174416405     1103     72689  0000-00-00 00:00:00
# 2       post -170321944   328776     72689  0000-00-00 00:00:00
# 3       post -170321944   334079     72689  0000-00-00 00:00:00
# 4       post -168996002    19811     72689  0000-00-00 00:00:00
# 5       post -166374599      757     72689  0000-00-00 00:00:00
# 6       post -165838780    59906     72689  0000-00-00 00:00:00
# 7       post -165838780    64006     72689  0000-00-00 00:00:00
# 8       post -165838780    64066     72689  0000-00-00 00:00:00
# 9       post -165838780    64120     72689  0000-00-00 00:00:00
# 10      post -165838780    64154     72689  0000-00-00 00:00:00
# 11      post -165838780    64504     72689  0000-00-00 00:00:00
# 12      post -165838780    64580     72689  0000-00-00 00:00:00
# 13      post -165838780    64745     72689  0000-00-00 00:00:00
# ...
